# %%
import nltk
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\MILKI\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
import requests
import urllib.request
response = urllib.request.urlopen('https://www.newsnationnow.com/space/planets-in-retrograde/')
html = response.read()
print(html)
# Out:
# b'\n<!doctype html>\n<html lang="en-US">\n<head>\n\t<meta charset="UTF-8">\n\t<meta name="viewport" content="width=device-width, initial-scale=1">\n\t\t<link rel="profile" href="https://gmpg.org/xfn/11">\n\t<link rel="preconnect" href="https://fonts.gstatic.com" crossorigin />\n\t<link rel="preload" as="style" href="https://fonts.googleapis.com/css?family=Lora:400,400i,700,700i|Roboto+Condensed:400,700&#038;display=swap" />\n\n\t\t\n\t<script>\r\n// Toggle Segment GA tracking mode\r\nwindow.gaCloudMode = false;\r\n</script>\n\t\t\t\n\t<!-- Cookies Consent Notice start -->\n\t<script src="https://ccpa.psg.nexstardigital.net/site/newsnationnow?perf=jsmin"></script> \t<!-- Cookies Consent Notice end -->\n\t\n\t\t\t<script type="text/javascript" src="https://www.newsnationnow.com/wp-content/plugins/universal-data-layer/js/udl.js?ver=1.3.0"></script>\n\t\t<script>\n\t\t\twindow.NXSTdata = window.NXSTdata || {};\n\t\t\twindow.NXSTdata.content = window.NXSTdata.content || {};\n\t\t\twindow.NXSTdata.page = window.NXSTdata.page || {};\n\t\t\twindow.NXSTdata.site = window.NXSTdata.site || {};\n\t\t\twindow.NXSTdata.ads = window.NXSTdata.ads || {};\n\t\t\twindow.NXSTdata.layout = window.NXSTdata.layout || {};\n\t\t\twindow.NXSTdata.privacy = window.NXSTdata.privacy || {};\n\t\t\twindow.NXSTdata.alerts = window.NXSTdata.alerts || {};\n\t\t\twindow.NXSTdata.location = window.NXSTdata.location || {};\n\t\t\twindow.NXSTdata.content = Object.assign( window.NXSTdata.content, {"title":"6 planets are in retrograde? Why do people care?","homepageTitle":"","metaKeywords":"space, planets, retrograde","socialTitle":"","pageType":"article","authorName":"David Tristan, Jocelina Joiner, Nexstar Media Wire","authorNonByline":"","description":"Six planets in our solar system are moving \\"in retrograde\\" right now, and that\'s getting a lot of people excited.","publicationDate":"2022-09-25T15:26:17-05:00","lastModifiedDate":"2022-09-25T15:26:19-05:00","publicationDayOfWeek":"Sunday","categoryList":["Space","U.S."],"primaryCategory":"Space","tagList":[],"wordCount":702,"paragraphCount":23,"imageCount":2,"videoCount":0,"slideshowCount":0,"pageId":2030722,"providerName":"Nexstar","isShared":false,"originalSource":"","sharingMode":"","pageDcode":["309","282","273","904","301","303","270","278","260","242","281","299","249","286"],"localId":"nxs-108-article-2030722","seoTitle":"Six planets are in retrograde? So what!","primaryCategoryId":688,"persistentId":"nxs-55-article-1292011","nlpSentiment":{"score":-0.1,"magnitude":7.4},"nlpCategories":{"\\/People & Society\\/Religion & Belief":0.96,"\\/Science\\/Astronomy":0.81},"nlpLocation":{"planets":0.11,"Earth":0.03,"planet":0.01,"Astrology sites":0.01},"nlpOther":{"Pluto":0.05,"sun":0.03,"order":0.03,"solar system":0.03,"orbiting planet":0.02,"relationships":0.01,"orbit speeds":0.01,"orbit":0.01,"mythology":0.01,"motions":0.01,"motion":0.01,"lot":0.01,"lives":0.01,"lengths":0.01,"jobs":0.01,"illusion":0.01,"idea":0.01,"heliocentrism":0.01,"fuss":0.01,"explanations":0.01,"energy swaying":0.01,"distances":0.01,"DeC":0.01,"cosmos":0.01,"challenges":0.01,"car stops":0.01,"yearsOrbits":0.01,"advice":0.01,"ventures":0.01,"variety":0.01,"vantage point":0.01,"talk":0.01,"stagnation":0.01,"speed":0.01,"science":0.01},"nlpOrganization":{"WHTM":0.02,"Mercury":0.02,"Helios":0.01},"nlpPerson":{"people":0.01,"god":0.01},"nlpWorkOfArt":{"horoscopes":0.01},"nlpConsumerGood":{"car":0.01,"stick":0.01}} )\n\t\t\twindow.NXSTdata.page = Object.assign( window.NXSTdata.page, {"canonicalUrl":"https:\\/\\/www.abc27.com\\/digital-originals\\/six-planets-are-in-retrograde-so-what\\/","ampUrl":"https:\\/\\/www.newsnationnow.com\\/space\\/planets-in-retrograde\\/amp\\/","urlHostname":"https:\\/\\/www.newsnationnow.com","urlSlug":"planets-in-retrograde","directoryPath":["space"]} )\n\t\t\twindow.NXSTdata.site = Object.assign( window.NXSTdata.site, {"activeTheme":"newsnation","appVersion":"wp","brandName":"NewsNation","callSign":"NewsNation", ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')
text = soup.get_text(strip = True)
print(text)
# Out:
# Six planets are in retrograde? So what!Skip to contentNewsNationSponsored ByToggle MenuOpen NavigationClose NavigationGoPrimary MenuUSPoliticsElections 2022MissingBusinessTechYour MoneyRecalls and Consumer AlertsHealthEntertainmentSportsImmigrationRace in AmericaCoronavirusVaccineWeatherClimateSpaceTop StoriesTropical Storm Ian becomes a hurricaneGallery IconGalleryTop StoriesFall foliage: Why leaves change colorTop StoriesHurricane vs. Cyclone vs. Typhoon: How are they different?DeSantis declares state of emergency for FloridaVideo IconVideoNASA delays Artemis I launch over Tropical Storm Ian threatHalf of Puerto Rico without power days after Hurricane FionaWorldOlympicsRussia At WarShowsEarly MorningMorning In AmericaNewsNation LiveNewsNation: Rush HourOn Balance with Leland VittertDan Abrams LiveBanfieldThe Hill🔴 NewsNation LiveHow To Watch NewsNationNewsNation TV ScheduleRadioMoreNetworkYour MorningMeet The TeamNewslettersFeedbackAdvertise with UsAppChannel FinderHow To Watch NewsNationNewsNation TV ScheduleGoGoGo6 planets are in retrograde? Why do people care?SpaceDavid Tristan,Jocelina Joiner,Nexstar Media WirePosted:Sep 25, 2022 / 03:26 PM CDT|Updated:Sep 25, 2022 / 03:26 PM CDT(NASA)(WHTM) — Six planets in our solar system are moving “in retrograde” right now, and that’s getting a lot of people excited.Astrology sites are full of explanations on how retrograde motions are affecting horoscopes, including talk of “stagnation in the cosmos,” “retrograde energy swaying” and “challenges to relationships” as well as advice to “avoid new ventures,” “stick to routine jobs” and “evaluate how we are transforming our lives.”NASA’s asteroid-smashing spacecraft nears its targetThere’s also a lot of bad science suggesting how the “planet slows down,” which certainly causes a lot of fuss over what is essentially an optical illusion.So what’s really going on when a planet travels in retrograde?To begin, the following planets (in order from the sun) will be moving in retrograde for a while:Mercury from Sept. 10 to Oct. 2Jupiter from July 28 to Nov. 23Saturn June 4 to Oct. 23Uranus Aug. 24 to Jan. 23Neptune June 28 to Dec. 4Pluto April 29 to Oct. 8 (Yeah, we know Pluto is a “dwarf planet,” but it’s still in an orbit, and it still displays retrograde motion.)According to NASA, retrograde motion is an “apparent” change in a planet’s movement through the sky when seen from Earth — when a planet appears to go backward in orbit. In other words, it’s the optical illusion that was just mentioned.Astronomers spot up to 170 giant rogue planets floating through spacePlanets, including Earth, orbit the sun. This idea is called heliocentrism. (Helios was the god of the sun in Greek mythology.)Because the planets orbit the sun at different distances, planets have years of different lengths:Mercury88 daysVenus225 daysMars687 days1.88 yearsJupiter4,333 days11.86 yearsSaturn10,759 days29.46 yearsUranus30,687 days84.01 yearsNeptune60,190 days164.79 yearsPluto(248.59 years)90,520 days248.59 yearsOrbits of Planets in days and yearsPlanets with shorter years will “overtake” slower-moving planets.Planets with different orbit speeds (NASA)As a faster orbiting planet overtakes a slower one, it will appear (from the vantage point of the faster-moving planet) as though the slower-moving planet stops moving forward and then drifts backward even though it is still moving at its original speed.“It is not REAL in that the planet does not physically start moving backwards in its orbit,” NASA states. “It just appears to do so because of the relative positions of the planet and Earth and how they are moving around the Sun.”Graphic showing the retrograde motion of Mars. Notice how Mars seems from Earth to travel in a loop. (NASA)We can actually see this effect on Earth. Imagine two cars traveling in the same direction in two different lanes. One travels slightly faster than the other. As the faster car overtakes the slower, it will appear (from the vantage point of the ...

# %%
tokens = [t for t in text.split()]
print(tokens)
# Out:
# ['Six', 'planets', 'are', 'in', 'retrograde?', 'So', 'what!Skip', 'to', 'contentNewsNationSponsored', 'ByToggle', 'MenuOpen', 'NavigationClose', 'NavigationGoPrimary', 'MenuUSPoliticsElections', '2022MissingBusinessTechYour', 'MoneyRecalls', 'and', 'Consumer', 'AlertsHealthEntertainmentSportsImmigrationRace', 'in', 'AmericaCoronavirusVaccineWeatherClimateSpaceTop', 'StoriesTropical', 'Storm', 'Ian', 'becomes', 'a', 'hurricaneGallery', 'IconGalleryTop', 'StoriesFall', 'foliage:', 'Why', 'leaves', 'change', 'colorTop', 'StoriesHurricane', 'vs.', 'Cyclone', 'vs.', 'Typhoon:', 'How', 'are', 'they', 'different?DeSantis', 'declares', 'state', 'of', 'emergency', 'for', 'FloridaVideo', 'IconVideoNASA', 'delays', 'Artemis', 'I', 'launch', 'over', 'Tropical', 'Storm', 'Ian', 'threatHalf', 'of', 'Puerto', 'Rico', 'without', 'power', 'days', 'after', 'Hurricane', 'FionaWorldOlympicsRussia', 'At', 'WarShowsEarly', 'MorningMorning', 'In', 'AmericaNewsNation', 'LiveNewsNation:', 'Rush', 'HourOn', 'Balance', 'with', 'Leland', 'VittertDan', 'Abrams', 'LiveBanfieldThe', 'Hill🔴', 'NewsNation', 'LiveHow', 'To', 'Watch', 'NewsNationNewsNation', 'TV', 'ScheduleRadioMoreNetworkYour', 'MorningMeet', 'The', 'TeamNewslettersFeedbackAdvertise', 'with', 'UsAppChannel', 'FinderHow', 'To', 'Watch', 'NewsNationNewsNation', 'TV', 'ScheduleGoGoGo6', 'planets', 'are', 'in', 'retrograde?', 'Why', 'do', 'people', 'care?SpaceDavid', 'Tristan,Jocelina', 'Joiner,Nexstar', 'Media', 'WirePosted:Sep', '25,', '2022', '/', '03:26', 'PM', 'CDT|Updated:Sep', '25,', '2022', '/', '03:26', 'PM', 'CDT(NASA)(WHTM)', '—', 'Six', 'planets', 'in', 'our', 'solar', 'system', 'are', 'moving', '“in', 'retrograde”', 'right', 'now,', 'and', 'that’s', 'getting', 'a', 'lot', 'of', 'people', 'excited.Astrology', 'sites', 'are', 'full', 'of', 'explanations', 'on', 'how', 'retrograde', 'motions', 'are', 'affecting', 'horoscopes,', 'including', 'talk', 'of', '“stagnation', 'in', 'the', 'cosmos,”', '“retrograde', 'energy', 'swaying”', 'and', '“challenges', 'to', 'relationships”', 'as', 'well', 'as', 'advice', 'to', '“avoid', 'new', 'ventures,”', '“stick', 'to', 'routine', 'jobs”', 'and', '“evaluate', 'how', 'we', 'are', 'transforming', 'our', 'lives.”NASA’s', 'asteroid-smashing', 'spacecraft', 'nears', 'its', 'targetThere’s', 'also', 'a', 'lot', 'of', 'bad', 'science', 'suggesting', 'how', 'the', '“planet', 'slows', 'down,”', 'which', 'certainly', 'causes', 'a', 'lot', 'of', 'fuss', 'over', 'what', 'is', 'essentially', 'an', 'optical', 'illusion.So', 'what’s', 'really', 'going', 'on', 'when', 'a', 'planet', 'travels', 'in', 'retrograde?To', 'begin,', 'the', 'following', 'planets', '(in', 'order', 'from', 'the', 'sun)', 'will', 'be', 'moving', 'in', 'retrograde', 'for', 'a', 'while:Mercury', 'from', 'Sept.', '10', 'to', 'Oct.', '2Jupiter', 'from', 'July', '28', 'to', 'Nov.', '23Saturn', 'June', '4', 'to', 'Oct.', '23Uranus', 'Aug.', '24', 'to', 'Jan.', '23Neptune', 'June', '28', 'to', 'Dec.', '4Pluto', 'April', '29', 'to', 'Oct.', '8', '(Yeah,', 'we', 'know', 'Pluto', 'is', 'a', '“dwarf', 'planet,”', 'but', 'it’s', 'still', 'in', 'an', 'orbit,', 'and', 'it', 'still', 'displays', 'retrograde', 'motion.)According', 'to', 'NASA,', 'retrograde', 'motion', 'is', 'an', '“apparent”', 'change', 'in', 'a', 'planet’s', 'movement', 'through', 'the', 'sky', 'when', 'seen', 'from', 'Earth', '—', 'when', 'a', 'planet', 'appears', 'to', 'go', 'backward', 'in', 'orbit.', 'In', 'other', 'words,', 'it’s', 'the', 'optical', 'illusion', 'that', 'was', 'just', 'mentioned.Astronomers', 'spot', 'up', 'to', '170', 'giant', 'rogue', 'planets', 'floating', 'through', 'spacePlanets,', 'including', 'Earth,', 'orbit', 'the', 'sun.', 'This', 'idea', 'is', 'called', 'heliocentrism.', '(Helios', 'was', 'the', 'god', 'of', 'the', 'sun', 'in', 'Greek', 'mythology.)Because', 'the', 'planets', 'orbit', 'the', 'sun', 'at', 'different', 'distances,', 'planets', 'have', 'years', 'of', 'different', 'lengths:Mercury88', 'daysVenus225 ...

# %%
from nltk.corpus import stopwords
sr = stopwords.words('english')
clean_tokens = tokens[:]
for token in tokens:
    if token in stopwords.words('english'):
        clean_tokens.remove(token)

# %%
freq = nltk.FreqDist(clean_tokens)
for key, val in freq.items():
    print(str(key)+':'+)
